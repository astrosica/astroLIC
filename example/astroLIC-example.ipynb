# %% [markdown]
# # Line Integral Convolution (LIC) for Astrophysics Polarization
# ### by J. L. Campbell

# %% [markdown]
# #### Import packages
# Everything we'll need is in `astroLIC.py` file. We'll use `imp.reload()` to make sure that any changes made to this file (if you choose to do so) will be updated. This cell will have to be re-run if changes are made to the file.

# %%
import sys
sys.path.append("../astroLIC/")

import imp
import astroLIC
imp.reload(astroLIC)
from astroLIC import *
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# #### Define files
# The following are the Stokes $I$, $Q$, and $U$ file names that will be used. Here I am using the 353 GHz _Planck_ maps at 4' resolution for Stokes $I$ and 80' resolution for $Q$ and $U$.

# %%
I_dir = "./data/I_COM_CompMap_ThermalDust-commander_2048_R2.00_S1-C.fits"
Q_dir = "./data/Q_COM_CompMap_IQU-thermaldust-gnilc-unires_2048_R3.00_S1-C.fits"
U_dir = "./data/U_COM_CompMap_IQU-thermaldust-gnilc-unires_2048_R3.00_S1-C.fits"

# %% [markdown]
# ### Run astroLIC

# %% [markdown]
# An example of just using the pixel coordinates:

# %%
astroLIC(I_dir,Q_dir,U_dir,length=0.25,toIAU=True,wcs=False)

# %% [markdown]
# And now using the WCS defined by the Stokes I FITS header:

# %%
astroLIC(I_dir,Q_dir,U_dir,length=0.25,toIAU=True,wcs=True)
